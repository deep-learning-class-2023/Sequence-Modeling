# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('GOOG.csv')
cols = list(df)[1:5]
y_col='Open'
print('{}'.format(cols))
df.head()
# Out:
# ['Open', 'High', 'Low', 'Close']
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2005-06-15  136.986542  138.132248  133.215668  136.886917  136.886917
# 1  2005-06-16  136.617920  138.630386  136.025146  138.201981  138.201981
# 2  2005-06-17  138.979065  139.626648  137.434860  139.626648  139.626648
# 3  2005-06-20  137.529510  143.297882  135.357651  142.814697  142.814697
# 4  2005-06-21  143.497131  144.607971  141.952927  143.382568  143.382568
#
#      Volume
# 0  41922600
# 1  25018100
# 2  20946900
# 3  42206900
# 4  30377900

# %%
df = df[cols].astype(str)
for i in cols:
    for j in range(0, len(df)):
        df[i][j] = df[i][j].replace(',', '')

df = df.astype(float)

# Using multiple features (predictors)
training_set = df.to_numpy()

print('Shape of training set == {}.'.format(training_set.shape))
training_set
# Out:
# Shape of training set == (3775, 4).
# array([[ 136.986542,  138.132248,  133.215668,  136.886917],
#        [ 136.61792 ,  138.630386,  136.025146,  138.201981],
#        [ 138.979065,  139.626648,  137.43486 ,  139.626648],
#        ...,
#        [1459.540039, 1474.259033, 1456.27002 , 1465.849976],
#        [1442.47998 , 1454.474976, 1402.      , 1403.839966],
#        [1428.48999 , 1437.      , 1386.02002 , 1413.180054]])

# %%
X = []
y = []

for i in range(60, training_set.shape[0]):
    X.append(training_set[i-60:i])
    y.append(training_set[i,0])

# %%
X,y = np.array(X),np.array(y)
X.shape
# Out:
# (3715, 60, 4)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (2489, 60, 4)
# (1226, 60, 4)

# %%
from keras import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential()

model.add(LSTM(units=60, activation='relu', return_sequences=True, input_shape= (x_train.shape[1],4)))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(x_train,y_train, epochs=50, batch_size=32, validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 3s 34ms/step - loss: 53577.1406 - val_loss: 8282.9971
# Epoch 2/50
# 78/78 [==============================] - 3s 33ms/step - loss: 48537.9922 - val_loss: 9403.3418
# Epoch 3/50
# 78/78 [==============================] - 2s 32ms/step - loss: 50654.4258 - val_loss: 4729.9248
# Epoch 4/50
# 78/78 [==============================] - 2s 31ms/step - loss: 51714.3477 - val_loss: 5705.2388
# Epoch 5/50
# 78/78 [==============================] - 2s 31ms/step - loss: 54444.3984 - val_loss: 26023.9590
# Epoch 6/50
# 78/78 [==============================] - 2s 32ms/step - loss: 57495.1172 - val_loss: 5260.3608
# Epoch 7/50
# 78/78 [==============================] - 2s 30ms/step - loss: 60418.4023 - val_loss: 38103.5742
# Epoch 8/50
# 78/78 [==============================] - 2s 32ms/step - loss: 58688.7969 - val_loss: 33864.9297
# Epoch 9/50
# 78/78 [==============================] - 2s 32ms/step - loss: 64539.6875 - val_loss: 21233.7617
# Epoch 10/50
# 78/78 [==============================] - 2s 32ms/step - loss: 63747.0078 - val_loss: 9415.8887
# 78/78 [==============================] - 3s 33ms/step - loss: 87665.6250 - val_loss: 120571.2734
# Epoch 36/50
# 78/78 [==============================] - 3s 32ms/step - loss: 92387.7656 - val_loss: 66835.7266
# Epoch 37/50
# 78/78 [==============================] - 2s 32ms/step - loss: 108923.5547 - val_loss: 45843.3867
# Epoch 38/50
# 78/78 [==============================] - 2s 32ms/step - loss: 122876.8906 - val_loss: 7832.2627
# Epoch 39/50
# 78/78 [==============================] - 2s 32ms/step - loss: 63083.2422 - val_loss: 11316.3271
# Epoch 40/50
# 78/78 [==============================] - 3s 32ms/step - loss: 93593.6016 - val_loss: 5785.5962
# Epoch 41/50
# 78/78 [==============================] - 3s 33ms/step - loss: 105676.7422 - val_loss: 13079.4414
# Epoch 42/50
# 78/78 [==============================] - 3s 33ms/step - loss: 90671.0781 - val_loss: 47698.0977
# Epoch 43/50
# 78/78 [==============================] - 2s 32ms/step - loss: 187377.3750 - val_loss: 7384.5679
# Epoch 44/50
# 78/78 [==============================] - 2s 32ms/step - loss: 205438.0625 - val_loss: 4732.9771
# Epoch 45/50
# 78/78 [==============================] - 3s 32ms/step - loss: 233022.8438 - val_loss: 2885461.5000
# Epoch 46/50
# 78/78 [==============================] - 2s 32ms/step - loss: 10617785.0000 - val_loss: 4604.2705
# Epoch 47/50
# 78/78 [==============================] - 3s 32ms/step - loss: 81984.0781 - val_loss: 134039.2031
# Epoch 48/50
# 78/78 [==============================] - 3s 32ms/step - loss: 132582.5781 - val_loss: 15479.6621
# Epoch 49/50
# 78/78 [==============================] - 3s 33ms/step - loss: 61841.1250 - val_loss: 6798.3848
# Epoch 50/50
# 78/78 [==============================] - 3s 34ms/step - loss: 62009.9141 - val_loss: 9505.1904

# %%
model.save('lstm_model.h5')

# %%
import numpy as np
from keras.models import load_model

model = load_model('lstm_model.h5')
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[1231.4594 ],
#        [ 175.78308],
#        [ 216.46144],
#        ...,
#        [1406.4716 ],
#        [ 151.52975],
#        [ 331.6188 ]], dtype=float32)

# %%
print(np.mean(np.abs(y_pred-y_test)))
# Out:
# 410.59449777999026

# %%
plt.figure(figsize=(14,5))
plt.plot(y_test, color='red', label='Real Google Stock Price')
plt.plot(y_pred, color='yellow', label='Predict Google Stock Price')
plt.title('Prediksi Google Stock Price')
plt.xlabel('Time')
plt.ylabel('GSP')
plt.legend()
plt.show()

# %%
real = []
predict = []
for i in range(0, 200):
    real.append(y_test[i])
    predict.append(y_pred[i])

# %%
plt.figure(figsize=(14,5))
plt.plot(real, color='red', label='Real Google Stock Price')
plt.plot(predict, color='yellow', label='Predict Google Stock Price')
plt.title('Prediksi Google Stock Price')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(50)

import matplotlib.pyplot as plt
plt.plot(epochs,loss,'r',label='train loss LSTM')
plt.plot(epochs,val_loss,'b',label='val loss LSTM')
plt.legend()
